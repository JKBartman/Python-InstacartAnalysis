# %% [markdown]
# # Task 4.6 Combining and Exporting Data

# %% [markdown]
# ## Contents
# ### Import libraries and assign path
# ### Import Orders-Products Combined df
# ### Merge Orders-products Combined with Products Checked
# ### Export Orders-Products Merged to Pkl file

# %% [markdown]
# # Import libraries and assign path

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
# assign path
path = r'C:\\Users\\jkbar\\OneDrive\\CareerFoundry\\Instacart Basket Analysis'

# %% [markdown]
# # Import Orders-Products Combined df

# %%
# 3 import order_products_combined df
df_orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 14)

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id eval_set  order_number  \
# 0           0             0   2539329        1    prior             1
# 1           0             0   2539329        1    prior             1
# 2           0             0   2539329        1    prior             1
# 3           0             0   2539329        1    prior             1
# 4           0             0   2539329        1    prior             1
#
#    orders_day_of_week  order_hour_of_day  days_since_last_order  first_order  \
# 0                   2                  8                    NaN         True
# 1                   2                  8                    NaN         True
# 2                   2                  8                    NaN         True
# 3                   2                  8                    NaN         True
# 4                   2                  8                    NaN         True
#
#    product_id  add_to_cart_order  reordered _merge
# ...

# %%
# drop unnamed column
df_orders_products_combined=df_orders_products_combined.drop(columns =['Unnamed: 0.1', 'Unnamed: 0'])

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_last_order  first_order  product_id  \
# 0                  8                    NaN         True         196
# 1                  8                    NaN         True       14084
# 2                  8                    NaN         True       12427
# 3                  8                    NaN         True       26088
# 4                  8                    NaN         True       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# 2                  3          0   both
# ...

# %% [markdown]
# # Merge Orders-products Combined with Products Checked

# %%
# 5 Merge orders_projects_combined with products_checked

# %%
# import products_checked
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# delete Unnamed column
df_prods = df_prods.drop('Unnamed: 0', axis=1)

# %%
# delete _merge column
df_orders_products_combined = df_orders_products_combined.drop('_merge', axis =1)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_last_order  first_order  product_id  \
# 0                  8                    NaN         True         196
# 1                  8                    NaN         True       14084
# 2                  8                    NaN         True       12427
# 3                  8                    NaN         True       26088
# 4                  8                    NaN         True       26405
#
#    add_to_cart_order  reordered
# 0                  1          0
# 1                  2          0
# 2                  3          0
# ...

# %%
df_orders_products_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 11 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   order_id               int64
#  1   user_id                int64
#  2   eval_set               object
#  3   order_number           int64
#  4   orders_day_of_week     int64
#  5   order_hour_of_day      int64
#  6   days_since_last_order  float64
#  7   first_order            bool
#  8   product_id             int64
#  9   add_to_cart_order      int64
#  10  reordered              int64
# dtypes: bool(1), float64(1), int64(8), object(1)
# memory usage: 2.4+ GB

# %%
df_merged_large.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    0.0         196                  1
# 1                  8                    0.0       14084                  2
# 2                  8                    0.0       12427                  3
# 3                  8                    0.0       26088                  4
# 4                  8                    0.0       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
# 6. Confirm results of the merge using the merge flag
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# # Export Orders-Products Merged to Pkl file

# %%
# 7. Export file as ords_prods_merge in 'suitable format' (pickle)
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))

# %%
df = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    0.0         196                  1
# 1                  8                    0.0       14084                  2
# 2                  8                    0.0       12427                  3
# 3                  8                    0.0       26088                  4
# 4                  8                    0.0       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...
