# %% [markdown]
# # 4.8 Grouping Data & Aggregating Variables

# %% [markdown]
# ## Contents
# ### 4.8 Lesson Exercise
# #### Import libraries and assign path
# #### Import ords_prods_merge dataframe
# #### Determine department mean
# #### Define loyalty flag
# #### Export updated DF

# %% [markdown]
# # 4.8 Lesson Exercise

# %% [markdown]
# # Import libraries and assign path

# %%
# import Libraries
import pandas as pd
import numpy as np
import os

# %%
# assign path
path = r'C:\Users\jkbar\OneDrive\CareerFoundry\Instacart Basket Analysis'

# %% [markdown]
# # Import ords_prods_merge dataframe

# %%
# import dataframe
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# create dataframe subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 20)

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    NaN         196                  1
# 1                  8                    NaN       14084                  2
# 2                  8                    NaN       12427                  3
# 3                  8                    NaN       26088                  4
# 4                  8                    NaN       26405                  5
#
#    reordered                             product_name  aisle_id  \
# 0          0                                     Soda        77
# 1          0  Organic Unsweetened Vanilla Almond Milk        91
# 2          0                      Original Beef Jerky        23
# 3          0               Aged White Cheddar Popcorn        23
# 4          0         XL Pick-A-Size Paper Towel Rolls        54
#
#    department_id  prices _merge    price_range_loc     busiest_day  \
# 0              7     9.0   both  Mid-range product  Regularly busy
# 1             16    12.5   both  Mid-range product  Regularly busy
# 2             19     4.4   both  Low-range product  Regularly busy
# 3             19     4.7   both  Low-range product  Regularly busy
# 4             17     1.0   both  Low-range product  Regularly busy
#
#      busiest_days busiest_period_of_day  first_order
# 0  Regularly busy        Average orders         True
# 1  Regularly busy        Average orders         True
# 2  Regularly busy        Average orders         True
# 3  Regularly busy        Average orders         True
# 4  Regularly busy        Average orders         True

# %%
df.groupby('product_name')

# %% [markdown]
# # Determine department mean

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2539329        1    prior             1                   2
# 2    2539329        1    prior             1                   2
# 3    2539329        1    prior             1                   2
# 4    2539329        1    prior             1                   2
# 5    2398795        1    prior             2                   3
# 6    2398795        1    prior             2                   3
# 7    2398795        1    prior             2                   3
# 8    2398795        1    prior             2                   3
# 9    2398795        1    prior             2                   3
# 10   2398795        1    prior             2                   3
# 11    473747        1    prior             3                   3
# 12    473747        1    prior             3                   3
# 13    473747        1    prior             3                   3
# 14    473747        1    prior             3                   3
#
#     order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                   8                    NaN         196                  1
# 1                   8                    NaN       14084                  2
# 2                   8                    NaN       12427                  3
# 3                   8                    NaN       26088                  4
# 4                   8                    NaN       26405                  5
# 5                   7                   15.0         196                  1
# 6                   7                   15.0       10258                  2
# 7                   7                   15.0       12427                  3
# 8                   7                   15.0       13176                  4
# 9                   7                   15.0       26088                  5
# 10                  7                   15.0       13032                  6
# 11                 12                   21.0         196                  1
# 12                 12                   21.0       12427                  2
# 13                 12                   21.0       10258                  3
# 14                 12                   21.0       25133                  4
#
#     reordered  ... aisle_id  department_id  prices  _merge    price_range_loc  \
# 0           0  ...       77              7     9.0    both  Mid-range product
# 1           0  ...       91             16    12.5    both  Mid-range product
# 2           0  ...       23             19     4.4    both  Low-range product
# 3           0  ...       23             19     4.7    both  Low-range product
# 4           0  ...       54             17     1.0    both  Low-range product
# 5           1  ...       77              7     9.0    both  Mid-range product
# 6           0  ...      117             19     3.0    both  Low-range product
# 7           1  ...       23             19     4.4    both  Low-range product
# 8           0  ...       24              4    10.3    both  Mid-range product
# 9           1  ...       23             19     4.7    both  Low-range product
# 10          0  ...      121             14     4.0    both  Low-range product
# 11          1  ...       77              7     9.0    both  Mid-range product
# 12          1  ...       23             19     4.4    both  Low-range product
# 13          1  ...      117             19     3.0    both  Low-range product
# 14          0  ...       21             16     8.6    both  Mid-range product
#
#        busiest_day    busiest_days busiest_period_of_day first_order  \
# 0   Regularly busy  Regularly busy        Average orders        True
# 1   Regularly busy  Regularly busy        Average orders        True
# 2   Regularly busy  Regularly busy        Average orders        True
# 3   Regularly busy  Regularly busy        Average orders        True
# 4   Regularly busy  Regularly busy        Average orders        True
# 5   Regularly busy    Slowest days        Average orders       False
# 6   Regularly busy    Slowest days        Average orders       False
# 7   Regularly busy    Slowest days        Average orders       False
# 8   Regularly busy    Slowest days        Average orders       False
# 9   Regularly busy    Slowest days        Average orders       False
# 10  Regularly busy    Slowest days        Average orders       False
# 11  Regularly busy    Slowest days        Average orders       False
# 12  Regularly busy    Slowest days        Average orders       False
# 13  Regularly busy    Slowest days        Average orders       False
# 14  Regularly busy    Slowest days        Average orders       False
#
#     max_order
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# 5          10
# 6          10
# 7          10
# 8          10
# 9          10
# 10         10
# 11         10
# 12         10
# 13         10
# 14         10
#
# [15 rows x 21 columns]

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Windows\Temp\ipykernel_31036\1681540670.py:1: FutureWarning: The provided callable <function max at 0x00000260CC625F80> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.tail()
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 32404854   2977660   206209    prior            13                   1
# 32404855   2977660   206209    prior            13                   1
# 32404856   2977660   206209    prior            13                   1
# 32404857   2977660   206209    prior            13                   1
# 32404858   2977660   206209    prior            13                   1
#
#           order_hour_of_day  days_since_last_order  product_id  \
# 32404854                 12                    7.0       14197
# 32404855                 12                    7.0       38730
# 32404856                 12                    7.0       31477
# 32404857                 12                    7.0        6567
# 32404858                 12                    7.0       22920
#
#           add_to_cart_order  reordered  ... aisle_id  department_id  prices  \
# 32404854                  5          1  ...        9              9     5.6
# 32404855                  6          0  ...        3             19     5.9
# 32404856                  7          0  ...        3             19     4.2
# 32404857                  8          0  ...        3             19     4.9
# 32404858                  9          0  ...      117             19     1.7
#
#           _merge    price_range_loc     busiest_day  busiest_days  \
# 32404854    both  Mid-range product  Regularly busy  Busiest days
# 32404855    both  Mid-range product  Regularly busy  Busiest days
# 32404856    both  Low-range product  Regularly busy  Busiest days
# 32404857    both  Low-range product  Regularly busy  Busiest days
# 32404858    both  Low-range product  Regularly busy  Busiest days
#
#          busiest_period_of_day first_order  max_order
# 32404854        Average orders       False         13
# 32404855        Average orders       False         13
# 32404856        Average orders       False         13
# 32404857        Average orders       False         13
# 32404858        Average orders       False         13
#
# [5 rows x 21 columns]

# %%
ords_prods_merge.groupby(['user_id'])

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2539329        1    prior             1                   2
# 2    2539329        1    prior             1                   2
# 3    2539329        1    prior             1                   2
# 4    2539329        1    prior             1                   2
# ..       ...      ...      ...           ...                 ...
# 95    738281        2    prior             4                   2
# 96   1673511        2    prior             5                   3
# 97   1673511        2    prior             5                   3
# 98   1673511        2    prior             5                   3
# 99   1673511        2    prior             5                   3
#
#     order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                   8                    NaN         196                  1
# 1                   8                    NaN       14084                  2
# 2                   8                    NaN       12427                  3
# 3                   8                    NaN       26088                  4
# 4                   8                    NaN       26405                  5
# ..                ...                    ...         ...                ...
# 95                 10                    8.0       21150                 13
# 96                 11                    8.0       47144                  1
# 97                 11                    8.0        5322                  2
# 98                 11                    8.0       17224                  3
# 99                 11                    8.0       38656                  4
#
#     reordered  ... aisle_id  department_id  prices  _merge    price_range_loc  \
# 0           0  ...       77              7     9.0    both  Mid-range product
# 1           0  ...       91             16    12.5    both  Mid-range product
# 2           0  ...       23             19     4.4    both  Low-range product
# 3           0  ...       23             19     4.7    both  Low-range product
# 4           0  ...       54             17     1.0    both  Low-range product
# ..        ...  ...      ...            ...     ...     ...                ...
# 95          0  ...       38              1     5.9    both  Mid-range product
# 96          0  ...       91             16    14.0    both  Mid-range product
# 97          0  ...        3             19     2.9    both  Low-range product
# 98          0  ...        3             19     1.6    both  Low-range product
# 99          0  ...        3             19     3.4    both  Low-range product
#
#        busiest_day    busiest_days busiest_period_of_day first_order  \
# 0   Regularly busy  Regularly busy        Average orders        True
# 1   Regularly busy  Regularly busy        Average orders        True
# 2   Regularly busy  Regularly busy        Average orders        True
# 3   Regularly busy  Regularly busy        Average orders        True
# 4   Regularly busy  Regularly busy        Average orders        True
# ..             ...             ...                   ...         ...
# 95  Regularly busy  Regularly busy           Most Orders       False
# 96  Regularly busy    Slowest days           Most Orders       False
# 97  Regularly busy    Slowest days           Most Orders       False
# 98  Regularly busy    Slowest days           Most Orders       False
# 99  Regularly busy    Slowest days           Most Orders       False
#
#     max_order
# 0          10
# 1          10
# 2          10
# 3          10
# 4          10
# ..        ...
# 95         14
# 96         14
# 97         14
# 98         14
# 99         14
#
# [100 rows x 21 columns]

# %% [markdown]
# # Define loyalty flag

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# 20        1      New customer             4
# 21        1      New customer             5
# 22        1      New customer             5
# 23        1      New customer             5
# 24        1      New customer             5
# 25        1      New customer             5
# 26        1      New customer             5
# 27        1      New customer             5
# 28        1      New customer             5
# 29        1      New customer             6
# 30        1      New customer             6
# 31        1      New customer             6
# 32        1      New customer             6
# 33        1      New customer             7
# 34        1      New customer             7
# 35        1      New customer             7
# 36        1      New customer             7
# 37        1      New customer             7
# 38        1      New customer             8
# 39        1      New customer             8
# 40        1      New customer             8
# 41        1      New customer             8
# 42        1      New customer             8
# 43        1      New customer             8
# 44        1      New customer             9
# 45        1      New customer             9
# 46        1      New customer             9
# 47        1      New customer             9
# 48        1      New customer             9
# 49        1      New customer             9
# 50        1      New customer            10
# 51        1      New customer            10
# 52        1      New customer            10
# 53        1      New customer            10
# 54        1      New customer            10
# 55        1      New customer            10
# 56        1      New customer            10
# 57        1      New customer            10
# 58        1      New customer            10
# 59        2  Regular customer             1

# %% [markdown]
# # Export updated DF

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
